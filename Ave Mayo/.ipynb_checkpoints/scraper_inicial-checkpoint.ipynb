# %%
import requests
from bs4 import BeautifulSoup

# Configuracin de entrada
url = "https://www.jumbo.cl/chocolates-galletas-y-snacks/chocolates?nombre_promo=destacados-chocolates-26092025"
headers = {"User-Agent": "Mozilla/5.0"} # Para que no nos bloqueen

# 1. Petici n al servidor
respuesta = requests.get(url, headers=headers)

# 2. Convertir el HTML en un objeto de Python
sopa = BeautifulSoup(respuesta.text, 'html.parser')

# 3. Buscar los datos (Ejemplo: buscar todos los t tulos)
# Cambia ’h2’ y ’nombre-de-la-clase’ por lo que inspeccionaste
resultados = sopa.find_all('div', class_='flex flex-col')

# 4. Mostrar en pantalla
for dato in resultados:
    print(f"Encontrado: {dato.text.strip()}")
# Out:
# Encontrado: $1.990$24.875 x kg
# Encontrado: $4.590$28.688 x kg
# Encontrado: $4.990$6.900$19.960 x kg
# Encontrado: $3.190$37.093 x kg
# Encontrado: $3.600$24.000 x kg
# Encontrado: $3.350$31.905 x kg
# Encontrado: $4.990$7.150$19.960 x kg
# Encontrado: $1.990$22.111 x kg
# Encontrado: $11.590$27.595 x kg
# Encontrado: $1.912$2.390$19.120 x kg
# Encontrado: $10.392$12.990$20.457 x kg
# Encontrado: $3.190$37.093 x kg
# Encontrado: $2.490$2.990$20.750 x kg
# Encontrado: $3.990$6.790$13.300 x kg
# Encontrado: $7.990$65.492 x kg
# Encontrado: $2.990$37.375 x kg
# Encontrado: $1.912$2.390$19.120 x kg
# Encontrado: $19.990$99.950 x kg
# Encontrado: $1.912$2.390$19.120 x kg
# Encontrado: $20.790$144.375 x kg
# Encontrado: $2.950$59.000 x kg
# Encontrado: $5.290$24.605 x kg
# Encontrado: $1.390$1.390 x un
# Encontrado: $2.793$3.990$27.930 x kg
# Encontrado: $2.990$37.375 x kg
# Encontrado: $2.990$33.222 x kg
# Encontrado: $3.050$14.524 x kg
# Encontrado: $1.912$2.390$19.120 x kg
# Encontrado: $4.990$83.167 x kg
# Encontrado: $1.890$23.625 x kg
# Encontrado: $1.690$2.450$1.690 x un
# Encontrado: $3.190$31.900 x kg
# Encontrado: $2.490$16.600 x kg
# Encontrado: $2.850$22.800 x kg
# Encontrado: $1.490$1.690$15.684 x kg
