# %%
from pymongo import MongoClient
import certifi

uri = "mongodb+srv://FelipeGutierrez:pepe1516@cluster0.6zjv54l.mongodb.net/?retryWrites=true&w=majority"

client = MongoClient(
    uri,
    tlsCAFile=certifi.where(),
    serverSelectionTimeoutMS=5000
)

try:
    print(client.server_info())
    print(" Conexión exitosa")
except Exception as e:
    print(" Error:", e)
# Out:
# ---------------------------------------------------------------------------
# LifetimeTimeout                           Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/srv_resolver.py:108, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#     107 try:
# --> 108     results = _resolve(
#     109         "_" + self.__srv + "._tcp." + self.__fqdn, "SRV", lifetime=self.__connect_timeout
#     110     )
#     111 except Exception as exc:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/srv_resolver.py:53, in _resolve(*args, **kwargs)
#      51     from dns import resolver
# ---> 53     return resolver.resolve(*args, **kwargs)
#      54 else:
#
# File /opt/conda/lib/python3.11/site-packages/dns/resolver.py:1572, in resolve(qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1563 """Query nameservers to find the answer to the question.
#    1564
#    1565 This is a convenience function that uses the default resolver
#    (...)
#    1569 parameters.
#    1570 """
# -> 1572 return get_default_resolver().resolve(
#    1573     qname,
#    1574     rdtype,
#    1575     rdclass,
#    1576     tcp,
#    1577     source,
#    1578     raise_on_no_answer,
#    1579     source_port,
#    1580     lifetime,
#    1581     search,
#    1582 )
#
# File /opt/conda/lib/python3.11/site-packages/dns/resolver.py:1328, in Resolver.resolve(self, qname, rdtype, rdclass, tcp, source, raise_on_no_answer, source_port, lifetime, search)
#    1327     time.sleep(backoff)
# -> 1328 timeout = self._compute_timeout(start, lifetime, resolution.errors)
#    1329 try:
#
# File /opt/conda/lib/python3.11/site-packages/dns/resolver.py:1084, in BaseResolver._compute_timeout(self, start, lifetime, errors)
#    1083 if duration >= lifetime:
# -> 1084     raise LifetimeTimeout(timeout=duration, errors=errors)
#    1085 return min(lifetime - duration, self.timeout)
#
# LifetimeTimeout: The resolution lifetime expired after 21.117 seconds: Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.
#
# The above exception was the direct cause of the following exception:
#
# ConfigurationError                        Traceback (most recent call last)
# Cell In[2], line 6
#       2 import certifi
#       4 uri = "mongodb+srv://FelipeGutierrez:pepe1516@cluster0.6zjv54l.mongodb.net/?retryWrites=true&w=majority"
# ----> 6 client = MongoClient(
#       7     uri,
#       8     tlsCAFile=certifi.where(),
#       9     serverSelectionTimeoutMS=5000
#      10 )
#      12 try:
#      13     print(client.server_info())
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:891, in MongoClient.__init__(self, host, port, document_class, tz_aware, connect, type_registry, **kwargs)
#     888     self._init_background()
#     890 if _IS_SYNC and connect:
# --> 891     self._get_topology()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1758, in MongoClient._get_topology(self)
#    1756 if not self._opened:
#    1757     if self._resolve_srv_info["is_srv"]:
# -> 1758         self._resolve_srv()
#    1759         self._init_background()
#    1760     self._topology.open()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:910, in MongoClient._resolve_srv(self)
#     906 if timeout is not None:
#     907     timeout = common.validate_timeout_or_none_or_zero(
#     908         keyword_opts.cased_key("connecttimeoutms"), timeout
#     909     )
# --> 910 res = uri_parser._parse_srv(
#     911     entity,
#     912     self._port,
#     913     validate=True,
#     914     warn=True,
#     915     normalize=False,
#     916     connect_timeout=timeout,
#     917     srv_service_name=srv_service_name,
#     918     srv_max_hosts=srv_max_hosts,
#     919 )
#     920 seeds.update(res["nodelist"])
#     921 opts = res["options"]
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/uri_parser.py:168, in _parse_srv(uri, default_port, validate, warn, normalize, connect_timeout, srv_service_name, srv_max_hosts)
#     166 connect_timeout = connect_timeout or options.get("connectTimeoutMS")
#     167 dns_resolver = _SrvResolver(fqdn, connect_timeout, srv_service_name, srv_max_hosts)
# --> 168 nodes = dns_resolver.get_hosts()
#     169 dns_options = dns_resolver.get_options()
#     170 if dns_options:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/srv_resolver.py:148, in _SrvResolver.get_hosts(self)
#     147 def get_hosts(self) -> list[tuple[str, Any]]:
# --> 148     _, nodes = self._get_srv_response_and_hosts(True)
#     149     return nodes
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/srv_resolver.py:122, in _SrvResolver._get_srv_response_and_hosts(self, encapsulate_errors)
#     119 def _get_srv_response_and_hosts(
#     120     self, encapsulate_errors: bool
#     121 ) -> tuple[resolver.Answer, list[tuple[str, Any]]]:
# --> 122     results = self._resolve_uri(encapsulate_errors)
#     124     # Construct address tuples
#     125     nodes = [
#     126         (maybe_decode(res.target.to_text(omit_final_dot=True)), res.port)  # type: ignore[attr-defined]
#     127         for res in results
#     128     ]
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/srv_resolver.py:116, in _SrvResolver._resolve_uri(self, encapsulate_errors)
#     114         raise
#     115     # Else, raise all errors as ConfigurationError.
# --> 116     raise ConfigurationError(str(exc)) from exc
#     117 return results
#
# ConfigurationError: The resolution lifetime expired after 21.117 seconds: Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.; Server Do53:127.0.0.11@53 answered The DNS operation timed out.

# %%
db = client["prueba"]
coleccion = db["personas"]

coleccion.insert_one({"nombre": "Jesús", "edad": 60})
# Out:
# InsertOneResult(ObjectId('69e7fadfe368e041f06047a5'), acknowledged=True)
