# %%
from pyspark.sql import SparkSession

# 1. Detener sesiones previas en memoria
try:
    spark.stop()
except:
    pass

# 2. Credenciales y URI limpia
USUARIO = "FelipeGutierrez"
CONTRASENA = "pepe1516"
MONGO_URI = f"mongodb+srv://{USUARIO}:{CONTRASENA}@cluster0.6zjv54l.mongodb.net/?retryWrites=true&w=majority&authSource=admin&appName=Cluster0"

# 3. Inicializar sesión de Spark con el conector oficial
spark = SparkSession.builder \
    .appName("Analisis_Canasta_Basica_FelipeGutierrez") \
    .config("spark.mongodb.read.connection.uri", MONGO_URI) \
    .config("spark.mongodb.write.connection.uri", MONGO_URI) \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate()

# 4. Lectura directa apuntando a los datos reales de tu captura
try:
    print("Conectando a MongoDB Atlas...")
    
    df_retail = spark.read.format("mongodb") \
        .option("database", "Canasta_db") \
        .option("collection", "Integracion_Final") \
        .load()
    
    print("\nConexión exitosa realizada con Spark.")
    print("Mostrando los primeros 100 productos de la canasta básica:")
    
    # Mostramos los datos estructurados
    df_retail.show(100, truncate=False)

except Exception as e:
    print("\n[ERROR] Ocurrió un problema en la lectura.")
    print(f"Detalle técnico:\n{e}")
# Out:
# Conectando a MongoDB Atlas...
#
# Conexión exitosa realizada con Spark.
# Mostrando los primeros 100 productos de la canasta básica:
# +------------------------+----------------+-------------------+------------------------------------------------------------------------------------------------+----------+--------------------------------------------------+-------+------------+------------+
# |_id                     |categoria       |fecha_captura      |imagen                                                                                          |marca     |nombre_producto                                   |precio |responsable |supermercado|
# +------------------------+----------------+-------------------+------------------------------------------------------------------------------------------------+----------+--------------------------------------------------+-------+------------+------------+
# |69f3cc22eabfa0da487e6572|Despensa General|2026-05-01 19:19:02|https://images.lider.cl/wmtcl?source=url[file:/productos/217aa.jpg]&scale=size[160x160]&sink    |GENÉRICA  |Salsa de Tomate Italiana Pack 6 Un Bolsa 200 g ...|3790.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6573|Arroz           |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/4791831a.jpg]&scale=size[160x160]&sink |TUCAPEL   |Arroz Tucapel Extra Fino Grado 2 Grano largo fi...|1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6574|Aceites         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/696785aa.jpg]&scale=size[160x160]&sink |ACUENTA   |Aceite Vegetal Botella 900 ml Acuenta             |1390.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6575|Harinas         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/3039a.jpg]&scale=size[160x160]&sink    |ACUENTA   |Harina Sin Polvos De Hornear 1 kg Acuenta...      |790.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6577|Aceites         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/2321ac.jpg]&scale=size[160x160]&sink   |ACE       |Aceite De Maravilla Botella Botella 1 L Chef...   |2850.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e657a|Aceites         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/861190a.jpg]&scale=size[160x160]&sink  |NETO      |Atún Lomito Aceite Lata Drenado 104 g - Neto 16...|1850.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e657b|Arroz           |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/2403a.jpg]&scale=size[160x160]&sink    |TUCAPEL   |Arroz Grado 1 Grano Largo Bolsa 1 kg Tucapel...   |2150.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e657c|Despensa General|2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/295139a.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Salsa de Tomate Toscana Bolognesa Doypack 200 g...|940.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6578|Harinas         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/4853839a.jpg]&scale=size[160x160]&sink |SELECTA   |Harina Sin Polvos De Hornear 2 kg Selecta...      |2000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6579|Despensa General|2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/297591a.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Jurel Natural Unico                               |1750.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6576|Pastas          |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/2713aa.jpg]&scale=size[160x160]&sink   |CAROZZI   |Fideo Pasta Spaghetti N°5 Bolsa 400 g Carozzi...  |990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e657d|Pastas          |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/296751ab.jpg]&scale=size[160x160]&sink |GENÉRICA  |Fideo Pasta Espirales N°56 Bolsa 400 g Lucchett...|970.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e657f|Azúcares        |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/2439ae.jpg]&scale=size[160x160]&sink   |IANSA     |Azúcar Rubia Granulada Bolsa 500 g Iansa          |1290.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6580|Conservas       |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/1409690a.jpg]&scale=size[160x160]&sink |NETO      |Atún Lomitos en Agua Drenado 91 g - Neto 140 g ...|1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6581|Arroz           |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/2405aa.jpg]&scale=size[160x160]&sink   |MIRAFLORES|Arroz Grado 1 Grano Largo Bolsa 1 Kg Miraflores...|2350.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e657e|Aceites         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/468939ab.jpg]&scale=size[160x160]&sink |MIRAFLORES|Aceite Maravilla Botella 900 ml Miraflores...     |2790.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6582|Azúcares        |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/4860442a.jpg]&scale=size[160x160]&sink |LIDER     |Azúcar Blanca Granulada 1.1 kg Lider              |1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6584|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/4807762a.jpg]&scale=size[160x160]&sink |ACUENTA   |Caballa En Agua 425 g Acuenta                     |1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6583|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/3359a.jpg]&scale=size[160x160]&sink    |ACUENTA   |Salsa de Tomate Natural Doypack 200 g Acuenta...  |270.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6585|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/4755913a.jpg]&scale=size[160x160]&sink |GENÉRICA  |Ketchup Regular Doypack 250 g Hellmann's          |1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6589|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/295129ab.jpg]&scale=size[160x160]&sink |CAROZZI   |Salsa de Tomate Oliva Doypack 200 g Carozzi...    |940.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e658a|Arroz           |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/4709883a.jpg]&scale=size[160x160]&sink |LA ROMA   |Arroz Grado 1 Grano Largo Bolsa 800 g La Romana...|1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6586|Salsas          |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/4444106ac.jpg]&scale=size[160x160]&sink|KRAFT     |Mayonesa Deli Doypack 850 g Kraft                 |2890.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6587|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/2735ad.jpg]&scale=size[160x160]&sink   |GENÉRICA  |Ketchup Regular Doypack 900 g Hellmann's          |2350.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6588|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/924631aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Premezcla Tortalista Sopaipilla Caja 350 g Sele...|2290.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e658b|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/2669ab.jpg]&scale=size[160x160]&sink   |NETO      |Jurel Natural Lata Drenado 300 g - Neto 425 g S...|1850.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e658c|Arroz           |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/770748aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Arroz Grado 1 Grano Largo y Delgado Bolsa 1 kg ...|1650.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6592|Arroz           |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/4858027a.jpg]&scale=size[160x160]&sink |BANQUETE  |Arroz Largo Ancho Grano 2 Banquete                |2000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e658d|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/294909af.jpg]&scale=size[160x160]&sink |GENÉRICA  |Endulzante Líquido Stevia Sucralosa Botella 250...|2650.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e658f|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/1301191ab.jpg]&scale=size[160x160]&sink|LIDER     |Puré de Papas Instantáneo con Leche 1 Kg Lider... |6490.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6591|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/321271aa.jpg]&scale=size[160x160]&sink |LIDER     |Mostaza Doypack 500 g Lider                       |1450.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e658e|Azúcares        |2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/579038a.jpg]&scale=size[160x160]&sink  |LIDER     |Azúcar Blanca Granulada Bolsa 1 kg Lider          |1190.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6590|Despensa General|2026-05-01 19:18:30|https://images.lider.cl/wmtcl?source=url[file:/productos/4481794aa.jpg]&scale=size[160x160]&sink|GENÉRICA  |Mostaza Doypack 470 g Hellmann's                  |1550.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6594|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/1069857a.jpg]&scale=size[160x160]&sink |ACUENTA   |Ají Crema Squeeze 240 g Acuenta                   |850.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6596|Pastas          |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/2717ac.jpg]&scale=size[160x160]&sink   |CAROZZI   |Fideo Pasta Tallarines N°87 Bolsa 400 g Carozzi...|990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6595|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/735082aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Gelatina Frambuesa 100 g Ambrosoli                |770.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6597|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/4597098a.jpg]&scale=size[160x160]&sink |KRAFT     |Ketchup Regular Doypack 450 g Kraft               |1790.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6598|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/933815a.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Salsa de Tomate Preparada Bolognesa Doypack 200...|750.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6593|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/1069849a.jpg]&scale=size[160x160]&sink |ACUENTA   |Ají Crema Bolsa 1000 g Acuenta                    |1650.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6599|Pastas          |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/3279aa.jpg]&scale=size[160x160]&sink   |CAROZZI   |Fideo Pasta Espirales N°49 Bolsa 400 g Carozzi... |990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e659a|Conservas       |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/1104836a.jpg]&scale=size[160x160]&sink |NETO      |Atún Agua Lata Drenado 104 g - Neto 160 g Van C...|1850.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e659b|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/4605610a.jpg]&scale=size[160x160]&sink |LIDER     |Salsa de Tomate Italiana Doypack 200 g Lider...   |550.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e659c|Pastas          |2026-05-01 19:21:26|https://images.lider.cl/wmtcl?source=url[file:/productos/829198a.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Sopa Sabor Pollo con Fideos (5 Porciones) Sobre...|450.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e659e|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/939533ab.jpg]&scale=size[160x160]&sink |LIDER     |Orégano Entero Deshidratado 50 g Lider            |890.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e659d|Pastas          |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/715313a.jpg]&scale=size[160x160]&sink  |CAROZZI   |Fideo Pasta Corbatas N°80 Bolsa 400 g Carozzi...  |990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e659f|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/4605607a.jpg]&scale=size[160x160]&sink |LIDER     |Salsa de Tomate Natural Doypack 200 g Lider...    |550.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a2|Despensa General|2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/589794aa.jpg]&scale=size[160x160]&sink |VIVO      |Compota Mifrut Pera 90 g Vivo                     |490.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a0|Pastas          |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/299553aa.jpg]&scale=size[160x160]&sink |CAROZZI   |Fideo Pasta Fettucinne N°88 Bolsa 400 g Carozzi...|990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a1|Harinas         |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/766010a.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Harina Sin Polvos De Hornear Bolsa 25 kg Acuent...|14990.0|Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a3|Aceites         |2026-05-01 19:18:31|https://images.lider.cl/wmtcl?source=url[file:/productos/2337aa.jpg]&scale=size[160x160]&sink   |ACUENTA   |Aceite Vegetal Bidón 5 L Acuenta                  |7890.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a5|Pastas          |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/299501aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Fideo Pasta Mostaccioli N°46 Bolsa 400 g Carozz...|990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a6|Azúcares        |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/11573ab.jpg]&scale=size[160x160]&sink  |LIDER     |Azúcar Blanca Granulada Bolsa 5 kg Lider          |4490.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a4|Legumbres       |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/531717ab.jpg]&scale=size[160x160]&sink |GENÉRICA  |Porotos Negros Listos Para Servir Caja Drenado ...|1390.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a7|Legumbres       |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/292577ab.jpg]&scale=size[160x160]&sink |NETO      |Porotos Blancos Caja Drenado 230 g - Neto 380 g...|1390.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a9|Despensa General|2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/288405ab.jpg]&scale=size[160x160]&sink |GENÉRICA  |Endulzante Líquido Stevia Botella 270 ml Daily... |2650.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ab|Harinas         |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/279311aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Harina Sin Polvos de Hornear Bolsa 1 kg Collico...|1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65a8|Pastas          |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/346375a.jpg]&scale=size[160x160]&sink  |ACUENTA   |Fideo Pasta Tallarines N°77 Bolsa 400 g Acuenta...|430.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65aa|Pastas          |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/880768a.jpg]&scale=size[160x160]&sink  |ACUENTA   |Fideo Pasta Corbatas Bolsa 400 g Acuenta          |430.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ad|Pastas          |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/296907ac.jpg]&scale=size[160x160]&sink |GENÉRICA  |Fideo Pasta Tallarines N°77 Bolsa 400 g Lucchet...|970.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65af|Despensa General|2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/299339aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Caldo Sabor Gallina (12 Tabletas) Caja 132 g Ma...|1450.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ae|Pastas          |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/299535ab.jpg]&scale=size[160x160]&sink |CAROZZI   |Fideo Pasta Rigatoni N°48 Bolsa 400 g Carozzi...  |990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b0|Aceites         |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/2331aa.jpg]&scale=size[160x160]&sink   |ACE       |Aceite Vegetal Botella 1 L Belmont                |2450.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ac|Pastas          |2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/2737a.jpg]&scale=size[160x160]&sink    |GENÉRICA  |Fideo Pasta Cabellos de Angel Corto Bolsa 400 g...|990.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b3|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/589792aa.jpg]&scale=size[160x160]&sink |VIVO      |Compota Mifrut Manzana 90 g Vivo                  |490.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b4|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/1032468af.jpg]&scale=size[160x160]&sink|IANSA     |Endulzante Líquido Alulosa Botella 250 ml Iansa...|2990.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b5|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/699592aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Caldo en Polvo Sabor Pollo (6 Sobres) Bolsa 48 ...|740.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b1|Despensa General|2026-05-01 19:18:43|https://images.lider.cl/wmtcl?source=url[file:/productos/3415aa.jpg]&scale=size[160x160]&sink   |GENÉRICA  |Caldo Sabor Gallina (8 Tabletas) Caja 88 g Magg...|1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b2|Harinas         |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/887854a.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Harina Todo Uso Domestico Bolsa 25 kg Collico...  |19590.0|Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b6|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/268230a.jpg]&scale=size[160x160]&sink  |NETO      |Duraznos en Cubitos Tarro Drenado 340 g - Neto ...|2150.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b8|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/711322a.jpg]&scale=size[160x160]&sink  |ACUENTA   |Sal Fina De Mesa 1 kg Acuenta                     |390.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b9|Azúcares        |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/2435ad.jpg]&scale=size[160x160]&sink   |IANSA     |Azúcar Flor Bolsa 500 g Iansa                     |1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65bb|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/6191ab.jpg]&scale=size[160x160]&sink   |NETO      |Duraznos en Cubitos Caja Drenado 200 g - Neto 3...|1250.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65bc|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/298583a.jpg]&scale=size[160x160]&sink  |ACUENTA   |Salsa de Soya 1 L Acuenta                         |2350.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65b7|Pastas          |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/5355a.jpg]&scale=size[160x160]&sink    |CAROZZI   |Fideo Pasta Ravioli Carne Bolsa 400 g Carozzi...  |2450.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ba|Pastas          |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/346251a.jpg]&scale=size[160x160]&sink  |ACUENTA   |Fideo Pasta Quifaros Bolsa 400 g Acuenta          |460.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65be|Pastas          |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/3275aa.jpg]&scale=size[160x160]&sink   |CAROZZI   |Fideo Pasta Caracoquesos Caja 296 g Carozzi...    |1890.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c1|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/699590aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Caldo en Polvo Sabor Carne (6 Sobres) Bolsa 48 ...|740.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65bd|Conservas       |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/10676a.jpg]&scale=size[160x160]&sink   |NETO      |Atún Desmenuzado Agua Lata Drenado 120 g - Neto...|700.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65bf|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/461833ab.jpg]&scale=size[160x160]&sink |GENÉRICA  |Caldo Sabor Costilla (8 Tabletas) Caja 80 g Mag...|1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c2|Salsas          |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/583720a.jpg]&scale=size[160x160]&sink  |ACUENTA   |Mayonesa Regular Doypack 800 g Acuenta            |2190.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c3|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/461831aa.jpg]&scale=size[160x160]&sink |MAGGI     |Caldo de Verduras (8 Tabletas) Caja 80 g Maggi... |1000.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c0|Pastas          |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/10703aa.jpg]&scale=size[160x160]&sink  |LUCCHETTI |Fideo Pasta Spaghetti N°5 Bolsa 400 g Lucchetti...|970.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c4|Arroz           |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/12167ab.jpg]&scale=size[160x160]&sink  |GENÉRICA  |Arroz Grado 2 Grano Largo y Ancho Bolsa 1 kg Li...|1490.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c5|Pastas          |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/296803ab.jpg]&scale=size[160x160]&sink |LUCCHETTI |Fideo Pasta Corbatas N°88 Bolsa 400 g Lucchetti...|970.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c6|Arroz           |2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/313269aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Arroz Grado 1 Grano Largo y Ancho Bolsa 1 kg Li...|1890.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c8|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/772683aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Caldo en Polvo Sabor Costilla (6 Sobres) Bolsa ...|740.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c7|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/531721ab.jpg]&scale=size[160x160]&sink |GENÉRICA  |Garbanzos Listos Para Servir Caja Drenado 230 g...|1390.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65c9|Despensa General|2026-05-01 19:18:44|https://images.lider.cl/wmtcl?source=url[file:/productos/959563aa.jpg]&scale=size[160x160]&sink |NETO      |Jurel Lomo Natural Lata Drenado 104 g - Neto 16...|1450.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ca|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/3433ac.jpg]&scale=size[160x160]&sink   |GENÉRICA  |Crema de Espárragos (5 Porciones) Sobre 68 g Ma...|630.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65cb|Azúcares        |2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/2437ad.jpg]&scale=size[160x160]&sink   |IANSA     |Azúcar Blanca Granulada Bolsa 1 Kg Iansa          |1350.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65cc|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/7923aa.jpg]&scale=size[160x160]&sink   |GENÉRICA  |Salsa de Tomate Italiana Doypack 200 g Pomarola...|770.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65ce|Azúcares        |2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/730289aa.jpg]&scale=size[160x160]&sink |ACUENTA   |Azúcar Blanca Granulada Bolsa 1 kg Acuenta...     |750.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65cd|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/4602456ac.jpg]&scale=size[160x160]&sink|IANSA     |Stevia Sucralosa Recarga 200 ml Iansa Cero K...   |2350.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65cf|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/4605193a.jpg]&scale=size[160x160]&sink |GENÉRICA  |Consomé Sabor Pollo (5 porciones) Sobre 50 g Ma...|590.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65d0|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/295115aa.jpg]&scale=size[160x160]&sink |GENÉRICA  |Salsa de Tomate Toscana Arrabbiata Doypack 200 ...|940.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65d1|Azúcares        |2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/8931ab.jpg]&scale=size[160x160]&sink   |IANSA     |Azúcar Blanca Granulada Bolsa 5 Kg Iansa          |5290.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65d2|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/3439a.jpg]&scale=size[160x160]&sink    |MAGGI     |Crema de Choclo (5 Porciones) Sobre 79 g Maggi... |630.0  |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65d3|Harinas         |2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/4584655a.jpg]&scale=size[160x160]&sink |GENÉRICA  |Harina Mezcla Dulce Pan Paquete 1 kg Pan          |3890.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65d4|Despensa General|2026-05-01 19:18:45|https://images.lider.cl/wmtcl?source=url[file:/productos/296617ab.jpg]&scale=size[160x160]&sink |GOURMET   |Salsa de Soya Botella 500 cc Gourmet              |2550.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e65d7|Despensa General|2026-05-01 19:19:00|https://images.lider.cl/wmtcl?source=url[file:/productos/3435a.jpg]&scale=size[160x160]&sink    |GENÉRICA  |Crema Sabor Pollo (5 Porciones) Sobre 72 g Magg...|630.0  |Jorge Chávez|Acuenta     |
# +------------------------+----------------+-------------------+------------------------------------------------------------------------------------------------+----------+--------------------------------------------------+-------+------------+------------+
# only showing top 100 rows

# %%
try:
    print("Conectando a MongoDB Atlas...")
    
    # IMPORTANTE: Aquí debe decir df_raw
    df_raw = spark.read.format("mongodb") \
        .option("database", "Canasta_db") \
        .option("collection", "Integracion_Final") \
        .load()
    
    print("Lectura finalizada. Ya puedes usar df_raw en otra celda.")
except Exception as e:
    print(f"Error: {e}")
# Out:
# Conectando a MongoDB Atlas...
# Lectura finalizada. Ya puedes usar df_raw en otra celda.

# %%
print(df_raw.count())
# Out:
# 5594

# %%
from pyspark.sql.functions import col

# 1. Quitamos duplicados usando tus columnas reales: "nombre_producto" y "supermercado"
df_clean = df_raw.dropDuplicates(["nombre_producto", "supermercado"]) \
    .filter(col("nombre_producto").isNotNull() & (col("nombre_producto") != "")) \
    .filter(col("precio").isNotNull() & (col("precio") != 0) & (col("precio") != "0.0"))

# 2. Contamos cuántos registros quedaron después de la limpieza
print(f"Total de registros limpios: {df_clean.count()}")
# Out:
# Total de registros limpios: 5594

# %%
# Generar el resumen estadístico descriptivo del precio real de los supermercados
df_clean.select("precio").describe().show()
# Out:
# +-------+------------------+
# |summary|            precio|
# +-------+------------------+
# |  count|              5594|
# |   mean|3690.1621380050055|
# | stddev| 6885.580189733287|
# |    min|             150.0|
# |    max|          102000.0|
# +-------+------------------+

# %%
from pyspark.sql.functions import col

# Agrupamos por supermercado y categoría, calculamos el precio promedio y ordenamos de mayor a menor
df_clean.groupBy("supermercado", "categoria") \
    .avg("precio") \
    .orderBy("avg(precio)", ascending=False) \
    .show(20, truncate=False)
# Out:
# +------------+------------------------------+------------------+
# |supermercado|categoria                     |avg(precio)       |
# +------------+------------------------------+------------------+
# |Cugat       |Leche en Polvo                |17990.0           |
# |Cugat       |Carnicería                    |9357.941176470587 |
# |Unimarc     |Lácteos, Huevos y Refrigerados|9088.284482758621 |
# |ACUENTA     |Carnicería                    |8317.055555555555 |
# |Cugat       |Huevos                        |6190.0            |
# |Cugat       |Fiambrería Y Embutidos        |5990.0            |
# |ACUENTA     |Cerdo                         |5314.809523809524 |
# |ACUENTA     |Huevos                        |5132.857142857143 |
# |Acuenta     |Aseo                          |4666.176470588235 |
# |ACUENTA     |Pescados y Mariscos           |4646.0            |
# |Acuenta     |Limpieza                      |4332.463768115942 |
# |ACUENTA     |Aves                          |4251.279069767442 |
# |Unimarc     |Despensa                      |4211.029458598726 |
# |Cugat       |Aceites                       |4207.333333333333 |
# |Acuenta     |Salsas                        |3935.5555555555557|
# |ACUENTA     |Lácteos/Fiambrería            |3419.137931034483 |
# |Acuenta     |Aceites                       |3343.793103448276 |
# |Acuenta     |Harinas                       |3302.2580645161293|
# |Santa Isabel|Despensa                      |3157.832402234637 |
# |ACUENTA     |Lácteos                       |2997.388535031847 |
# +------------+------------------------------+------------------+
# only showing top 20 rows

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 1. Convertimos una muestra del 20% a Pandas para no saturar la memoria del contenedor
pdf = df_clean.sample(False, 0.2).toPandas()

# 2. Configurar el estilo del gráfico
plt.figure(figsize=(12, 6))
sns.boxplot(x='supermercado', y='precio', data=pdf)

# 3. Personalizar títulos y etiquetas en pesos chilenos
plt.title("Distribución de Precios de la Canasta Básica por Supermercado ($ CLP)", fontsize=14, fontweight='bold')
plt.xlabel("Supermercado", fontsize=12)
plt.ylabel("Precio en Pesos ($)", fontsize=12)

# Rotar los nombres de los supermercados si son largos (Lider, Acuenta, etc.)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# 4. Mostrar el gráfico limpia
plt.tight_layout()
plt.show()

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, regexp_extract, when, lit, udf, regexp_replace
from pyspark.sql.types import FloatType, StringType, IntegerType
import re

# 1. Credenciales reales y URI limpia de tu proyecto
USUARIO = "FelipeGutierrez"
CONTRASENA = "pepe1516"
MONGO_URI = f"mongodb+srv://{USUARIO}:{CONTRASENA}@cluster0.6zjv54l.mongodb.net/?retryWrites=true&w=majority&authSource=admin&appName=Cluster0"

# 2. Inicializar la sesión de Spark con tu AppName del proyecto
spark = SparkSession.builder \
    .appName("Analisis_Canasta_Basica_FelipeGutierrez") \
    .config("spark.mongodb.read.connection.uri", MONGO_URI) \
    .config("spark.mongodb.write.connection.uri", MONGO_URI) \
    .config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:10.1.1") \
    .getOrCreate()

# 3. Carga de datos crudos apuntando a tu Base de Datos y Colección del Hito
df_raw = spark.read.format("mongodb") \
    .option("database", "Canasta_db") \
    .option("collection", "Integracion_Final") \
    .load()

print("¡Sesión de Spark iniciada y datos cargados en 'df_raw' con éxito!")
# Out:
# ¡Sesión de Spark iniciada y datos cargados en 'df_raw' con éxito!

# %%
# Mostramos las primeras 5 filas completas de tu canasta básica
df_raw.show(5, truncate=False) 

# Imprimimos la estructura y tipos de datos de tus columnas en Atlas
df_raw.printSchema()
# Out:
# +------------------------+----------------+-------------------+-----------------------------------------------------------------------------------------------+--------+--------------------------------------------------+------+------------+------------+
# |_id                     |categoria       |fecha_captura      |imagen                                                                                         |marca   |nombre_producto                                   |precio|responsable |supermercado|
# +------------------------+----------------+-------------------+-----------------------------------------------------------------------------------------------+--------+--------------------------------------------------+------+------------+------------+
# |69f3cc22eabfa0da487e6572|Despensa General|2026-05-01 19:19:02|https://images.lider.cl/wmtcl?source=url[file:/productos/217aa.jpg]&scale=size[160x160]&sink   |GENÉRICA|Salsa de Tomate Italiana Pack 6 Un Bolsa 200 g ...|3790.0|Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6573|Arroz           |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/4791831a.jpg]&scale=size[160x160]&sink|TUCAPEL |Arroz Tucapel Extra Fino Grado 2 Grano largo fi...|1000.0|Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6574|Aceites         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/696785aa.jpg]&scale=size[160x160]&sink|ACUENTA |Aceite Vegetal Botella 900 ml Acuenta             |1390.0|Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6575|Harinas         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/3039a.jpg]&scale=size[160x160]&sink   |ACUENTA |Harina Sin Polvos De Hornear 1 kg Acuenta...      |790.0 |Jorge Chávez|Acuenta     |
# |69f3cc22eabfa0da487e6577|Aceites         |2026-05-01 19:18:29|https://images.lider.cl/wmtcl?source=url[file:/productos/2321ac.jpg]&scale=size[160x160]&sink  |ACE     |Aceite De Maravilla Botella Botella 1 L Chef...   |2850.0|Jorge Chávez|Acuenta     |
# +------------------------+----------------+-------------------+-----------------------------------------------------------------------------------------------+--------+--------------------------------------------------+------+------------+------------+
# only showing top 5 rows
#
# root
#  |-- _id: string (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- fecha_captura: string (nullable = true)
#  |-- imagen: string (nullable = true)
#  |-- marca: string (nullable = true)
#  |-- nombre_producto: string (nullable = true)
#  |-- precio: double (nullable = true)
#  |-- responsable: string (nullable = true)
#  |-- supermercado: string (nullable = true)

# %%
from pyspark.sql.functions import col

# Creamos el DataFrame optimizado para el análisis numérico/categórico de tu proyecto
df_clustering = df_raw.select(
    col("marca").alias("marca"),                           # Tu columna de marca original
    col("supermercado").alias("supermercado"),             # Cadena de retail (Lider, Acuenta, etc.)
    col("categoria").alias("categoria"),                   # Pasillo o tipo de alimento
    col("precio").cast("double").alias("precio")           # Aseguramos que el precio sea numérico (Double)
)

# Mostramos el esquema para verificar que los tipos cambiaron correctamente
df_clustering.printSchema()

# Vemos una muestra de los primeros 5 registros transformados
df_clustering.show(5)
# Out:
# root
#  |-- marca: string (nullable = true)
#  |-- supermercado: string (nullable = true)
#  |-- categoria: string (nullable = true)
#  |-- precio: double (nullable = true)
#
# +--------+------------+----------------+------+
# |   marca|supermercado|       categoria|precio|
# +--------+------------+----------------+------+
# |GENÉRICA|     Acuenta|Despensa General|3790.0|
# | TUCAPEL|     Acuenta|           Arroz|1000.0|
# | ACUENTA|     Acuenta|         Aceites|1390.0|
# | ACUENTA|     Acuenta|         Harinas| 790.0|
# |     ACE|     Acuenta|         Aceites|2850.0|
# +--------+------------+----------------+------+
# only showing top 5 rows

# %%
from pyspark.ml.feature import StringIndexer, VectorAssembler, StandardScaler, PCA

# 1. Convertimos los textos (supermercado y categoría) a índices numéricos para poder meterlos al modelo
indexer_super = StringIndexer(inputCol="supermercado", outputCol="supermercado_index").fit(df_clustering)
df_indexed = indexer_super.transform(df_clustering)

indexer_cat = StringIndexer(inputCol="categoria", outputCol="categoria_index").fit(df_indexed)
df_ready = indexer_cat.transform(df_indexed)

# 2. Vectorizamos las nuevas columnas numéricas de tu proyecto
# Ahora sí tiene sentido: evaluamos el precio combinado con el origen del producto
assembler = VectorAssembler(
    inputCols=["precio", "supermercado_index", "categoria_index"], 
    outputCol="features"
)
df_vector = assembler.transform(df_ready)

# 3. Escalamos los datos (esencial para K-Means y PCA)
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures", withStd=True, withMean=False)
scaler_model = scaler.fit(df_vector)
df_scaled = scaler_model.transform(df_vector)

# 4. Reducción de dimensionalidad con PCA a 2 componentes para tu gráfico bidimensional
pca = PCA(k=2, inputCol="scaledFeatures", outputCol="pcaFeatures")
pca_model = pca.fit(df_scaled)
df_pca = pca_model.transform(df_scaled)

# Mostramos el resultado final listo para el K-Means
print("¡Pipeline de características completado con éxito!")
df_pca.select("supermercado", "categoria", "precio", "pcaFeatures").show(5, truncate=False)
# Out:
# ¡Pipeline de características completado con éxito!
# +------------+----------------+------+----------------------------------------+
# |supermercado|categoria       |precio|pcaFeatures                             |
# +------------+----------------+------+----------------------------------------+
# |Acuenta     |Despensa General|3790.0|[1.1492734669968987,-0.6654139788545208]|
# |Acuenta     |Arroz           |1000.0|[3.505363965564012,-1.1644106109161023] |
# |Acuenta     |Aceites         |1390.0|[2.844729365454077,-0.9648739270941616] |
# |Acuenta     |Harinas         |790.0 |[3.187514810255604,-1.007975873683967]  |
# |Acuenta     |Aceites         |2850.0|[2.7997824732812924,-1.1691527843013247]|
# +------------+----------------+------+----------------------------------------+
# only showing top 5 rows

# %%
import pandas as pd

# 1. Extraemos la matriz de componentes desde tu modelo PCA entrenado
loadings = pca_model.pc.toArray()

# 2. Definimos tus variables reales en el mismo orden en que se vectorizaron
variables = ["precio", "supermercado_index", "categoria_index"]

# 3. Creamos el DataFrame de Pandas para cruzar los coeficientes con tus columnas
pc_loadings = pd.DataFrame(loadings, columns=['PC1', 'PC2'], index=variables)

print("Matriz de Influencia (Loadings) para la Canasta Básica:")
print(pc_loadings)
# Out:
# Matriz de Influencia (Loadings) para la Canasta Básica:
#                          PC1       PC2
# precio             -0.211976 -0.963410
# supermercado_index  0.703133 -0.033777
# categoria_index     0.678727 -0.265896

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Extraemos una muestra del 20% para proteger la memoria y seleccionamos las columnas reales
pdf_pca_raw = df_pca.sample(False, 0.2).select("pcaFeatures", "marca").toPandas()

# 2. Convertimos el vector de Spark a columnas numéricas de Pandas (PC1 y PC2)
pdf_pca_raw[['PC1', 'PC2']] = pd.DataFrame(pdf_pca_raw['pcaFeatures'].apply(lambda x: x.toArray()).tolist())

# 3. Calculamos límites estadísticos (percentiles 1-99) para evitar que los valores atípicos alejen el gráfico
pc1_min, pc1_max = np.percentile(pdf_pca_raw['PC1'], [1, 99])
pc2_min, pc2_max = np.percentile(pdf_pca_raw['PC2'], [1, 99])

# 4. Configurar y dibujar el Scatterplot bidimensional del PCA
plt.figure(figsize=(11, 7))
sns.set_style("darkgrid")

sns.scatterplot(
    data=pdf_pca_raw, 
    x='PC1', 
    y='PC2', 
    color='teal',     # Color único para ver la densidad de dispersión
    s=60, 
    alpha=0.5,        # Transparencia clave para ver dónde se acumulan más productos
    edgecolor=None
)

# 5. Aplicamos el zoom centrado en la masa principal de datos
plt.xlim(pc1_min - 1, pc1_max + 1)
plt.ylim(pc2_min - 1, pc2_max + 1)

# Personalización con los datos de tu Hito
plt.title('Distribución Espacial de la Canasta Básica de Supermercados (PCA)', fontsize=15, fontweight='bold')
plt.xlabel('Componente Principal 1 (Eje de mayor varianza)', fontsize=12)
plt.ylabel('Componente Principal 2 (Eje secundario)', fontsize=12)

plt.tight_layout()
plt.show()

# %%
from pyspark.ml.clustering import KMeans

# 1. Definimos el número óptimo de clústeres para la canasta básica
k_optimo = 3
kmeans_final = KMeans(featuresCol='scaledFeatures', k=k_optimo, seed=42)

# 2. Entrenamos el modelo con los datos escalados de tus supermercados
model_final = kmeans_final.fit(df_scaled)

# 3. Asignamos los clústeres (0, 1 o 2) a cada registro de la base de datos
df_clusters = model_final.transform(df_scaled)

# 4. Mostramos el resultado con tus columnas reales y la predicción del clúster
df_clusters.select("supermercado", "categoria", "marca", "precio", "prediction").show(400, truncate=False)
# Out:
# +------------+----------------+----------+-------+----------+
# |supermercado|categoria       |marca     |precio |prediction|
# +------------+----------------+----------+-------+----------+
# |Acuenta     |Despensa General|GENÉRICA  |3790.0 |0         |
# |Acuenta     |Arroz           |TUCAPEL   |1000.0 |1         |
# |Acuenta     |Aceites         |ACUENTA   |1390.0 |1         |
# |Acuenta     |Harinas         |ACUENTA   |790.0  |1         |
# |Acuenta     |Aceites         |ACE       |2850.0 |1         |
# |Acuenta     |Aceites         |NETO      |1850.0 |1         |
# |Acuenta     |Arroz           |TUCAPEL   |2150.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |940.0  |0         |
# |Acuenta     |Harinas         |SELECTA   |2000.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1750.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |970.0  |2         |
# |Acuenta     |Azúcares        |IANSA     |1290.0 |1         |
# |Acuenta     |Conservas       |NETO      |1000.0 |1         |
# |Acuenta     |Arroz           |MIRAFLORES|2350.0 |1         |
# |Acuenta     |Aceites         |MIRAFLORES|2790.0 |1         |
# |Acuenta     |Azúcares        |LIDER     |1000.0 |1         |
# |Acuenta     |Despensa General|ACUENTA   |1000.0 |0         |
# |Acuenta     |Despensa General|ACUENTA   |270.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1000.0 |0         |
# |Acuenta     |Despensa General|CAROZZI   |940.0  |0         |
# |Acuenta     |Arroz           |LA ROMA   |1000.0 |1         |
# |Acuenta     |Salsas          |KRAFT     |2890.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2350.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |2290.0 |0         |
# |Acuenta     |Despensa General|NETO      |1850.0 |0         |
# |Acuenta     |Arroz           |GENÉRICA  |1650.0 |1         |
# |Acuenta     |Arroz           |BANQUETE  |2000.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2650.0 |0         |
# |Acuenta     |Despensa General|LIDER     |6490.0 |0         |
# |Acuenta     |Despensa General|LIDER     |1450.0 |0         |
# |Acuenta     |Azúcares        |LIDER     |1190.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1550.0 |0         |
# |Acuenta     |Despensa General|ACUENTA   |850.0  |0         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |770.0  |0         |
# |Acuenta     |Despensa General|KRAFT     |1790.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |750.0  |0         |
# |Acuenta     |Despensa General|ACUENTA   |1650.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Conservas       |NETO      |1850.0 |1         |
# |Acuenta     |Despensa General|LIDER     |550.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |450.0  |2         |
# |Acuenta     |Despensa General|LIDER     |890.0  |0         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Despensa General|LIDER     |550.0  |0         |
# |Acuenta     |Despensa General|VIVO      |490.0  |0         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Harinas         |GENÉRICA  |14990.0|1         |
# |Acuenta     |Aceites         |ACUENTA   |7890.0 |1         |
# |Acuenta     |Pastas          |GENÉRICA  |990.0  |2         |
# |Acuenta     |Azúcares        |LIDER     |4490.0 |1         |
# |Acuenta     |Legumbres       |GENÉRICA  |1390.0 |1         |
# |Acuenta     |Legumbres       |NETO      |1390.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2650.0 |0         |
# |Acuenta     |Harinas         |GENÉRICA  |1000.0 |1         |
# |Acuenta     |Pastas          |ACUENTA   |430.0  |2         |
# |Acuenta     |Pastas          |ACUENTA   |430.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |970.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |1450.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Aceites         |ACE       |2450.0 |1         |
# |Acuenta     |Pastas          |GENÉRICA  |990.0  |2         |
# |Acuenta     |Despensa General|VIVO      |490.0  |0         |
# |Acuenta     |Despensa General|IANSA     |2990.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |740.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1000.0 |0         |
# |Acuenta     |Harinas         |GENÉRICA  |19590.0|1         |
# |Acuenta     |Despensa General|NETO      |2150.0 |0         |
# |Acuenta     |Despensa General|ACUENTA   |390.0  |0         |
# |Acuenta     |Azúcares        |IANSA     |1000.0 |1         |
# |Acuenta     |Despensa General|NETO      |1250.0 |0         |
# |Acuenta     |Despensa General|ACUENTA   |2350.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |2450.0 |2         |
# |Acuenta     |Pastas          |ACUENTA   |460.0  |2         |
# |Acuenta     |Pastas          |CAROZZI   |1890.0 |2         |
# |Acuenta     |Despensa General|GENÉRICA  |740.0  |0         |
# |Acuenta     |Conservas       |NETO      |700.0  |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1000.0 |0         |
# |Acuenta     |Salsas          |ACUENTA   |2190.0 |1         |
# |Acuenta     |Despensa General|MAGGI     |1000.0 |0         |
# |Acuenta     |Pastas          |LUCCHETTI |970.0  |2         |
# |Acuenta     |Arroz           |GENÉRICA  |1490.0 |1         |
# |Acuenta     |Pastas          |LUCCHETTI |970.0  |2         |
# |Acuenta     |Arroz           |GENÉRICA  |1890.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |740.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1390.0 |0         |
# |Acuenta     |Despensa General|NETO      |1450.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |630.0  |0         |
# |Acuenta     |Azúcares        |IANSA     |1350.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |770.0  |0         |
# |Acuenta     |Azúcares        |ACUENTA   |750.0  |1         |
# |Acuenta     |Despensa General|IANSA     |2350.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |590.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |940.0  |0         |
# |Acuenta     |Azúcares        |IANSA     |5290.0 |1         |
# |Acuenta     |Despensa General|MAGGI     |630.0  |0         |
# |Acuenta     |Harinas         |GENÉRICA  |3890.0 |1         |
# |Acuenta     |Despensa General|GOURMET   |2550.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |630.0  |0         |
# |Acuenta     |Despensa General|NETO      |1690.0 |0         |
# |Acuenta     |Harinas         |GENÉRICA  |1190.0 |1         |
# |Acuenta     |Legumbres       |GENÉRICA  |1390.0 |1         |
# |Acuenta     |Aceites         |ACE       |2650.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |940.0  |0         |
# |Acuenta     |Aceites         |ACUENTA   |2390.0 |1         |
# |Acuenta     |Despensa General|ACUENTA   |2290.0 |0         |
# |Acuenta     |Arroz           |GENÉRICA  |1190.0 |1         |
# |Acuenta     |Pastas          |GENÉRICA  |450.0  |2         |
# |Acuenta     |Legumbres       |ACUENTA   |1950.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |560.0  |0         |
# |Acuenta     |Harinas         |GENÉRICA  |1250.0 |1         |
# |Acuenta     |Legumbres       |NETO      |1390.0 |1         |
# |Acuenta     |Legumbres       |LIDER     |950.0  |1         |
# |Acuenta     |Arroz           |GENÉRICA  |450.0  |1         |
# |Acuenta     |Despensa General|LOBOS     |420.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |450.0  |0         |
# |Acuenta     |Despensa General|MAGGI     |630.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |2000.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |560.0  |0         |
# |Acuenta     |Legumbres       |BANQUETE  |2000.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2150.0 |0         |
# |Acuenta     |Despensa General|NETO      |1490.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |2450.0 |2         |
# |Acuenta     |Despensa General|MAGGI     |890.0  |0         |
# |Acuenta     |Harinas         |SELECTA   |1990.0 |1         |
# |Acuenta     |Arroz           |ACUENTA   |850.0  |1         |
# |Acuenta     |Arroz           |TUCAPEL   |1390.0 |1         |
# |Acuenta     |Arroz           |GENÉRICA  |740.0  |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1950.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |740.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |560.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |450.0  |2         |
# |Acuenta     |Harinas         |LIDER     |890.0  |1         |
# |Acuenta     |Despensa General|NETO      |1650.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |450.0  |0         |
# |Acuenta     |Pastas          |ACUENTA   |430.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |770.0  |0         |
# |Acuenta     |Aceites         |LIDER     |1650.0 |1         |
# |Acuenta     |Pastas          |CAROZZI   |990.0  |2         |
# |Acuenta     |Aceites         |NETO      |1390.0 |1         |
# |Acuenta     |Legumbres       |LIDER     |950.0  |1         |
# |Acuenta     |Harinas         |ACUENTA   |790.0  |1         |
# |Acuenta     |Despensa General|GENÉRICA  |740.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |560.0  |0         |
# |Acuenta     |Pastas          |ACUENTA   |430.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |630.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |450.0  |2         |
# |Acuenta     |Despensa General|LIDER     |2990.0 |0         |
# |Acuenta     |Despensa General|LUCCHETTI |770.0  |0         |
# |Acuenta     |Despensa General|MAGGI     |1000.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |1250.0 |2         |
# |Acuenta     |Salsas          |KRAFT     |6590.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |740.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |1090.0 |2         |
# |Acuenta     |Arroz           |GENÉRICA  |1950.0 |1         |
# |Acuenta     |Harinas         |ACUENTA   |3990.0 |1         |
# |Acuenta     |Harinas         |GENÉRICA  |1250.0 |1         |
# |Acuenta     |Despensa General|LIDER     |4690.0 |0         |
# |Acuenta     |Conservas       |NETO      |1350.0 |1         |
# |Acuenta     |Pastas          |LUCCHETTI |970.0  |2         |
# |Acuenta     |Salsas          |KRAFT     |9890.0 |1         |
# |Acuenta     |Aceites         |NETO      |1350.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2250.0 |0         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Aceites         |ACE       |8990.0 |1         |
# |Acuenta     |Harinas         |LIDER     |890.0  |1         |
# |Acuenta     |Pastas          |LUCCHETTI |970.0  |2         |
# |Acuenta     |Harinas         |SELECTA   |7090.0 |1         |
# |Acuenta     |Salsas          |KRAFT     |4490.0 |1         |
# |Acuenta     |Harinas         |SELECTA   |1350.0 |1         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Harinas         |SELECTA   |1350.0 |1         |
# |Acuenta     |Aceites         |LIDER     |1890.0 |1         |
# |Acuenta     |Salsas          |LIDER     |3890.0 |1         |
# |Acuenta     |Salsas          |LIDER     |3390.0 |1         |
# |Acuenta     |Aceites         |ACE       |8390.0 |1         |
# |Acuenta     |Aceites         |ACE       |5190.0 |1         |
# |Acuenta     |Pastas          |LUCCHETTI |970.0  |2         |
# |Acuenta     |Despensa General|KRAFT     |2790.0 |0         |
# |Acuenta     |Despensa General|NETO      |1450.0 |0         |
# |Acuenta     |Harinas         |GENÉRICA  |17990.0|1         |
# |Acuenta     |Despensa General|CAROZZI   |1390.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |590.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |970.0  |2         |
# |Acuenta     |Despensa General|NETO      |1650.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |2690.0 |0         |
# |Acuenta     |Despensa General|NETO      |1750.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1750.0 |0         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Despensa General|LIDER     |1890.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |590.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |2250.0 |0         |
# |Acuenta     |Despensa General|NETO      |2290.0 |0         |
# |Acuenta     |Despensa General|LIDER     |3490.0 |0         |
# |Acuenta     |Despensa General|NETO      |2290.0 |0         |
# |Acuenta     |Aceites         |LIDER     |4690.0 |1         |
# |Acuenta     |Aceites         |ACE       |4590.0 |1         |
# |Acuenta     |Salsas          |GENÉRICA  |4790.0 |1         |
# |Acuenta     |Despensa General|LIDER     |2590.0 |0         |
# |Acuenta     |Despensa General|LIDER     |1390.0 |0         |
# |Acuenta     |Aceites         |LIDER     |3000.0 |1         |
# |Acuenta     |Harinas         |GENÉRICA  |1050.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2290.0 |0         |
# |Acuenta     |Harinas         |LIDER     |2190.0 |1         |
# |Acuenta     |Pastas          |CAROZZI   |830.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |590.0  |0         |
# |Acuenta     |Harinas         |GENÉRICA  |1690.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |6290.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |830.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |950.0  |2         |
# |Acuenta     |Harinas         |GENÉRICA  |1050.0 |1         |
# |Acuenta     |Despensa General|ACUENTA   |760.0  |0         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Despensa General|NETO      |2450.0 |0         |
# |Acuenta     |Despensa General|LIDER     |2490.0 |0         |
# |Acuenta     |Harinas         |LIDER     |1550.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1790.0 |0         |
# |Acuenta     |Pastas          |CAROZZI   |830.0  |2         |
# |Acuenta     |Despensa General|ACUENTA   |1450.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1750.0 |0         |
# |Acuenta     |Harinas         |SELECTA   |1650.0 |1         |
# |Acuenta     |Despensa General|LIDER     |550.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1290.0 |0         |
# |Acuenta     |Despensa General|NETO      |2150.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |2000.0 |0         |
# |Acuenta     |Despensa General|ACUENTA   |830.0  |0         |
# |Acuenta     |Despensa General|NETO      |2350.0 |0         |
# |Acuenta     |Despensa General|LIDER     |2290.0 |0         |
# |Acuenta     |Salsas          |GENÉRICA  |3890.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |490.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1490.0 |0         |
# |Acuenta     |Despensa General|LIDER     |1990.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1350.0 |0         |
# |Acuenta     |Salsas          |LIDER     |3390.0 |1         |
# |Acuenta     |Legumbres       |LIDER     |950.0  |1         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |490.0  |0         |
# |Acuenta     |Despensa General|LIDER     |950.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |3990.0 |0         |
# |Acuenta     |Despensa General|VIVO      |660.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |780.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |1250.0 |0         |
# |Acuenta     |Despensa General|NETO      |3390.0 |0         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |1250.0 |0         |
# |Acuenta     |Despensa General|NETO      |2790.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |760.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |580.0  |2         |
# |Acuenta     |Despensa General|VIVO      |840.0  |0         |
# |Acuenta     |Despensa General|NETO      |990.0  |0         |
# |Acuenta     |Pastas          |CAROZZI   |830.0  |2         |
# |Acuenta     |Salsas          |LIDER     |2290.0 |1         |
# |Acuenta     |Pastas          |GENÉRICA  |520.0  |2         |
# |Acuenta     |Harinas         |GENÉRICA  |1350.0 |1         |
# |Acuenta     |Despensa General|VIVO      |840.0  |0         |
# |Acuenta     |Despensa General|ACUENTA   |850.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |9590.0 |0         |
# |Acuenta     |Pastas          |LIDER     |750.0  |2         |
# |Acuenta     |Salsas          |LIDER     |1250.0 |1         |
# |Acuenta     |Harinas         |GENÉRICA  |1090.0 |1         |
# |Acuenta     |Despensa General|NETO      |2990.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |780.0  |2         |
# |Acuenta     |Despensa General|NETO      |900.0  |0         |
# |Acuenta     |Harinas         |LIDER     |2290.0 |1         |
# |Acuenta     |Despensa General|LUCCHETTI |970.0  |0         |
# |Acuenta     |Despensa General|NETO      |2990.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |450.0  |0         |
# |Acuenta     |Despensa General|ACUENTA   |1650.0 |0         |
# |Acuenta     |Despensa General|NETO      |2690.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |2990.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |3890.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |3490.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |1190.0 |2         |
# |Acuenta     |Despensa General|NETO      |9590.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |930.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |930.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |930.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |930.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |930.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |440.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |490.0  |0         |
# |Acuenta     |Legumbres       |NETO      |610.0  |1         |
# |Acuenta     |Aceites         |NETO      |1000.0 |1         |
# |Acuenta     |Despensa General|NETO      |2690.0 |0         |
# |Acuenta     |Despensa General|NETO      |1250.0 |0         |
# |Acuenta     |Despensa General|ACUENTA   |1450.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |930.0  |0         |
# |Acuenta     |Despensa General|NETO      |2350.0 |0         |
# |Acuenta     |Despensa General|NETO      |1550.0 |0         |
# |Acuenta     |Despensa General|NETO      |630.0  |0         |
# |Acuenta     |Legumbres       |NETO      |630.0  |1         |
# |Acuenta     |Despensa General|NETO      |1990.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1950.0 |0         |
# |Acuenta     |Despensa General|NETO      |1650.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1590.0 |0         |
# |Acuenta     |Despensa General|NETO      |2750.0 |0         |
# |Acuenta     |Despensa General|NETO      |1590.0 |0         |
# |Acuenta     |Despensa General|NETO      |2290.0 |0         |
# |Acuenta     |Harinas         |GENÉRICA  |1150.0 |1         |
# |Acuenta     |Despensa General|NETO      |2390.0 |0         |
# |Acuenta     |Harinas         |SELECTA   |1990.0 |1         |
# |Acuenta     |Harinas         |GENÉRICA  |1850.0 |1         |
# |Acuenta     |Harinas         |GENÉRICA  |1190.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1650.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1750.0 |0         |
# |Acuenta     |Salsas          |GENÉRICA  |4890.0 |1         |
# |Acuenta     |Despensa General|NETO      |3990.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1390.0 |0         |
# |Acuenta     |Despensa General|LIDER     |550.0  |0         |
# |Acuenta     |Despensa General|GOURMET   |1250.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |2590.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |530.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1450.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |1450.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |4190.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |1250.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |1390.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |1650.0 |0         |
# |Acuenta     |Despensa General|BANQUETE  |1950.0 |0         |
# |Acuenta     |Despensa General|IANSA     |2950.0 |0         |
# |Acuenta     |Despensa General|LIDER     |3690.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |3190.0 |0         |
# |Acuenta     |Despensa General|IANSA     |3890.0 |0         |
# |Acuenta     |Legumbres       |IANSA     |3990.0 |1         |
# |Acuenta     |Legumbres       |GENÉRICA  |1750.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |1090.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1090.0 |0         |
# |Acuenta     |Pastas          |LUCCHETTI |2190.0 |2         |
# |Acuenta     |Pastas          |GENÉRICA  |2750.0 |2         |
# |Acuenta     |Pastas          |GENÉRICA  |950.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |950.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |780.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |780.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |780.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |1390.0 |2         |
# |Acuenta     |Pastas          |GENÉRICA  |990.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |990.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |890.0  |2         |
# |Acuenta     |Pastas          |GENÉRICA  |990.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |2250.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |890.0  |2         |
# |Acuenta     |Despensa General|CAROZZI   |1790.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |850.0  |0         |
# |Acuenta     |Aceites         |ACE       |1690.0 |1         |
# |Acuenta     |Despensa General|LIDER     |440.0  |0         |
# |Acuenta     |Despensa General|LIDER     |1390.0 |0         |
# |Acuenta     |Despensa General|LIDER     |370.0  |0         |
# |Acuenta     |Despensa General|LOBOS     |1350.0 |0         |
# |Acuenta     |Despensa General|MAGGI     |2690.0 |0         |
# |Acuenta     |Aceites         |ACE       |14490.0|1         |
# |Acuenta     |Despensa General|LIDER     |2450.0 |0         |
# |Acuenta     |Despensa General|LIDER     |460.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |1290.0 |2         |
# |Acuenta     |Pastas          |GENÉRICA  |1290.0 |2         |
# |Acuenta     |Despensa General|GOURMET   |5290.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |6290.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |4590.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |6290.0 |0         |
# |Acuenta     |Despensa General|GOURMET   |1850.0 |0         |
# |Acuenta     |Despensa General|LIDER     |740.0  |0         |
# |Acuenta     |Despensa General|LIDER     |770.0  |0         |
# |Acuenta     |Despensa General|GOURMET   |2190.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |2850.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |2950.0 |0         |
# |Acuenta     |Azúcares        |LIDER     |640.0  |1         |
# |Acuenta     |Azúcares        |LIDER     |640.0  |1         |
# |Acuenta     |Azúcares        |LIDER     |640.0  |1         |
# |Acuenta     |Despensa General|GOURMET   |1250.0 |0         |
# |Acuenta     |Azúcares        |LIDER     |640.0  |1         |
# |Acuenta     |Azúcares        |LIDER     |640.0  |1         |
# |Acuenta     |Despensa General|OMO       |3390.0 |0         |
# |Acuenta     |Legumbres       |GENÉRICA  |2290.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |2290.0 |0         |
# |Acuenta     |Despensa General|LUCCHETTI |990.0  |0         |
# |Acuenta     |Azúcares        |GENÉRICA  |1850.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |770.0  |0         |
# |Acuenta     |Pastas          |GENÉRICA  |890.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |3290.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |950.0  |2         |
# |Acuenta     |Despensa General|GENÉRICA  |3550.0 |0         |
# |Acuenta     |Despensa General|IANSA     |2650.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |990.0  |0         |
# |Acuenta     |Despensa General|IANSA     |3390.0 |0         |
# |Acuenta     |Despensa General|IANSA     |2850.0 |0         |
# |Acuenta     |Legumbres       |IANSA     |2990.0 |1         |
# |Acuenta     |Despensa General|LIDER     |320.0  |0         |
# |Acuenta     |Despensa General|LIDER     |430.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1050.0 |0         |
# |Acuenta     |Pastas          |GENÉRICA  |890.0  |2         |
# |Acuenta     |Despensa General|LIDER     |2750.0 |0         |
# |Acuenta     |Despensa General|LIDER     |960.0  |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1190.0 |0         |
# |Acuenta     |Despensa General|GENÉRICA  |1190.0 |0         |
# |Acuenta     |Arroz           |GENÉRICA  |2650.0 |1         |
# |Acuenta     |Salsas          |KRAFT     |3590.0 |1         |
# |Acuenta     |Pastas          |GENÉRICA  |890.0  |2         |
# |Acuenta     |Azúcares        |LIDER     |2150.0 |1         |
# |Acuenta     |Despensa General|GENÉRICA  |810.0  |0         |
# +------------+----------------+----------+-------+----------+
# only showing top 400 rows

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# 1. Cruzamos la información: Aplicamos el modelo K-Means al DataFrame que ya contiene el PCA
df_viz_final = model_final.transform(df_pca)

# 2. Pasamos una muestra del 20% a Pandas para no colapsar la memoria del driver de Spark
pdf_visual = df_viz_final.sample(False, 0.2).select("pcaFeatures", "prediction", "marca").toPandas()

# 3. Extraemos las coordenadas numéricas individuales (PC1 y PC2) del vector de Spark
pdf_visual[['PC1', 'PC2']] = pd.DataFrame(pdf_visual['pcaFeatures'].apply(lambda x: x.toArray()).tolist())

# 4. Calculamos límites estadísticos (percentiles 1-99) para centrar el gráfico eliminando ruidos extremos
pc1_min, pc1_max = np.percentile(pdf_visual['PC1'], [1, 99])
pc2_min, pc2_max = np.percentile(pdf_visual['PC2'], [1, 99])

# 5. Generamos el gráfico de dispersión a todo color
plt.figure(figsize=(13, 8))
sns.set_style("darkgrid")

# Pintamos los puntos usando 'prediction' en el parámetro hue para diferenciar los grupos
sns.scatterplot(
    data=pdf_visual, 
    x='PC1', 
    y='PC2', 
    hue='prediction', 
    palette='viridis',  # Paleta de colores limpia y profesional (Morado, Verde, Amarillo)
    s=80, 
    alpha=0.7,          # Transparencia para observar las zonas de solapamiento
    edgecolor=None
)

# Aplicamos el zoom óptimo centrado
plt.xlim(pc1_min - 1, pc1_max + 1)
plt.ylim(pc2_min - 1, pc2_max + 1)

# Personalización final para la entrega de tu Hito
plt.title(f'Segmentación de la Canasta Básica: Clústeres en Espacio PCA (k={k_optimo})', fontsize=15, fontweight='bold')
plt.xlabel('Componente Principal 1 (Eje económico principal)', fontsize=12)
plt.ylabel('Componente Principal 2 (Eje de dispersión secundario)', fontsize=12)
plt.legend(title='Clúster Asignado', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=11)

plt.tight_layout()
plt.show()

# %%
# Guardamos los datos con tus clusters en la carpeta de la Semana 10
df_clusters.write.mode("overwrite").parquet("/home/jovyan/work/semanas/Semana 10/Untitled")

# Guardo todo el modelo K-Means para clasificar datos nuevos de supermercados
model_final.save("/home/jovyan/work/semanas/Semana 10/kmeans_retail_v1")

# %%
from pyspark.sql import SparkSession

# 1. Iniciamos Spark en este nuevo notebook
spark = SparkSession.builder \
    .appName("Semana12_Supervisados_FelipeGutierrez") \
    .getOrCreate()

# 2. Leemos DIRECTAMENTE los datos (Todo en una sola línea continua)
ruta_datos = "/home/jovyan/work/semanas/Semana 10/Untitled"
df_clusters = spark.read.parquet(ruta_datos)

# 3. Verificamos que cargó mostrando el total de registros
print(f"¡Datos cargados con éxito desde la Semana 10!")
print(f"Total de registros listos: {df_clusters.count()}")
# Out:
# ¡Datos cargados con éxito desde la Semana 10!
# Total de registros listos: 5594

# %%
from pyspark.ml.classification import DecisionTreeClassifier
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# 1. Renombramos 'prediction' a 'label' para el modelo supervisado
df_supervisado = df_clusters.withColumnRenamed("prediction", "label")

# 2. Dividimos los datos en Entrenamiento (70%) y Prueba (30%) con una semilla fija
train_data, test_data = df_supervisado.randomSplit([0.7, 0.3], seed=42)

# 3. Imprimimos los resultados para verificar las muestras
print(f"Datos de entrenamiento (70%): {train_data.count()}")
print(f"Datos de prueba (30%): {test_data.count()}")
# Out:
# Datos de entrenamiento (70%): 3995
# Datos de prueba (30%): 1599

# %%
from pyspark.ml.classification import DecisionTreeClassifier

# 1. Configurar el modelo supervisado
# Usamos 'scaledFeatures' como entrada y 'label' (el clúster del K-Means) como el grupo a predecir
dt = DecisionTreeClassifier(featuresCol="scaledFeatures", labelCol="label", maxDepth=5, seed=42)

# 2. Entrenar el modelo con el 70% de los datos (train_data)
dt_model = dt.fit(train_data)

# 3. Hacer predicciones sobre el 30% de los datos de prueba restantes (test_data)
predictions_supervisadas = dt_model.transform(test_data)

# 4. Mostrar las predicciones adaptadas a las columnas de tus supermercados
predictions_supervisadas.select(
    "supermercado", 
    "categoria", 
    "marca", 
    "precio", 
    "label", 
    "prediction"
).show(10, truncate=False)
# Out:
# +------------+----------------+-------+-------+-----+----------+
# |supermercado|categoria       |marca  |precio |label|prediction|
# +------------+----------------+-------+-------+-----+----------+
# |Acuenta     |Aceites         |ACE    |1190.0 |1    |1.0       |
# |Acuenta     |Aceites         |ACE    |2650.0 |1    |1.0       |
# |Acuenta     |Aceites         |ACE    |3690.0 |1    |1.0       |
# |Acuenta     |Aceites         |ACE    |4590.0 |1    |1.0       |
# |Acuenta     |Aceites         |ACE    |14490.0|1    |1.0       |
# |Acuenta     |Despensa General|ACE    |570.0  |0    |0.0       |
# |Acuenta     |Despensa General|ACE    |2890.0 |0    |0.0       |
# |ACUENTA     |Aves            |ACUENTA|2800.0 |2    |2.0       |
# |ACUENTA     |Elaborados      |ACUENTA|2800.0 |1    |1.0       |
# |ACUENTA     |Lácteos         |ACUENTA|2590.0 |2    |2.0       |
# +------------+----------------+-------+-------+-----+----------+
# only showing top 10 rows

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# 1. Configurar el evaluador multiclasificación cruzando la etiqueta real con la predicción del árbol
evaluator = MulticlassClassificationEvaluator(
    labelCol="label", 
    predictionCol="prediction", 
    metricName="accuracy"
)

# 2. Calcular la precisión (Accuracy) evaluando el DataFrame de las predicciones
accuracy = evaluator.evaluate(predictions_supervisadas)

# 3. Imprimir el resultado final formateado como porcentaje
print(f"Precisión del Árbol de Decisión (Accuracy): {accuracy * 100:.2f}%")
# Out:
# Precisión del Árbol de Decisión (Accuracy): 100.00%

# %%
# 1. Imprimimos el encabezado para el reporte
print("=== ESTRUCTURA LÓGICA DEL ÁRBOL DE DECISIÓN ===")

# 2. Mostramos de forma nativa las reglas condicionales del modelo entrenado
print(dt_model.toDebugString)
# Out:
# === ESTRUCTURA LÓGICA DEL ÁRBOL DE DECISIÓN ===
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_1f272c55e587, depth=2, numNodes=7, numClasses=3, numFeatures=3
#   If (feature 2 <= 0.557465020125409)
#    If (feature 1 <= 1.8661856457744237)
#     Predict: 0.0
#    Else (feature 1 > 1.8661856457744237)
#     Predict: 2.0
#   Else (feature 2 > 0.557465020125409)
#    If (feature 2 <= 2.4687736605553825)
#     Predict: 2.0
#    Else (feature 2 > 2.4687736605553825)
#     Predict: 1.0

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
from sklearn.tree import DecisionTreeClassifier as SklearnClassifier

# 1. Convertimos nuestro DataFrame de Spark a Pandas para Scikit-Learn
# NOTA: Reemplaza "precio", "supermercado_index", "categoria_index" por los nombres exactos de tus columnas
columnas_interes = ["precio", "supermercado_index", "categoria_index", "label"]
df_pandas = df_supervisado.select(columnas_interes).toPandas()

# 2. Separamos las características (X) y la etiqueta objetivo (y)
nombres_features = ["precio", "supermercado_index", "categoria_index"]
X_muestra = df_pandas[nombres_features]
y_muestra = df_pandas["label"]

# 3. Creamos y entrenamos el clon de Scikit-Learn
# Limitamos la profundidad (max_depth=3) para que el gráfico quepa bien en la pantalla y se lea perfecto
sk_dt = SklearnClassifier(max_depth=3, random_state=42)
sk_dt.fit(X_muestra, y_muestra)

# 4. Configuramos los nombres de los clústeres para que sea didáctico
nombres_clases = [f"Cluster {int(c)}" for c in sorted(y_muestra.unique())]

# 5. Dibujamos el árbol con sus ramas, nodos y colores estratégicos
plt.figure(figsize=(20, 10), dpi=100)
plot_tree(
    sk_dt,
    feature_names=nombres_features,
    class_names=nombres_clases,
    filled=True,      # Aplica colores según la clase mayoritaria de productos
    rounded=True,     # Bordes redondeados estéticos para la entrega
    fontsize=12       # Tamaño de letra legible para las reglas de decisión
)

plt.title("Árbol de Decisión: Ingeniería Inversa del K-Means (Semana 12)", fontsize=18, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Definimos el Accuracy del Árbol de Decisión que ya calculamos
accuracy_dt = accuracy 

print("==================================================")
print("  RESULTADOS DE MODELOS SUPERVISADOS (SEMANA 12)  ")
print("==================================================")
print(f"1. Decision Tree Accuracy:       {accuracy_dt * 100:.2f}%")
print("3. SVM (OneVsRest) Accuracy:     (Pendiente de entrenamiento)")
print("4. Regresión Logística Accuracy: (Pendiente de entrenamiento)")
print("==================================================")
# Out:
# ==================================================
#   RESULTADOS DE MODELOS SUPERVISADOS (SEMANA 12)
# ==================================================
# 1. Decision Tree Accuracy:       100.00%
# 3. SVM (OneVsRest) Accuracy:     (Pendiente de entrenamiento)
# 4. Regresión Logística Accuracy: (Pendiente de entrenamiento)
# ==================================================

# %%
from pyspark.ml.feature import VectorAssembler, StandardScaler

# 1. Creamos el VectorAssembler excluyendo el precio (usamos los índices categóricos de tu proyecto)
assembler_regresion = VectorAssembler(
    inputCols=["supermercado_index", "categoria_index"],
    outputCol="features_regresion"
)
df_vector_reg = assembler_regresion.transform(df_clusters)

# 2. Escalamos las características para que tengan la misma magnitud matemática
scaler_reg = StandardScaler(inputCol="features_regresion", outputCol="scaledFeatures_regresion")
scaler_model_reg = scaler_reg.fit(df_vector_reg)
df_para_regresion = scaler_model_reg.transform(df_vector_reg)

# 3. Renombramos tu variable objetivo real a 'label_precio'
df_para_regresion = df_para_regresion.withColumnRenamed("precio", "label_precio")

# =======================================================================
# Borramos la columna prediction del K-Means anterior 
# para evitar que colisione con las predicciones que generará la Regresión Lineal
df_para_regresion = df_para_regresion.drop("prediction")
# =======================================================================

# 4. Dividimos los datos adaptados en Entrenamiento (70%) y Prueba (30%)
train_reg, test_reg = df_para_regresion.randomSplit([0.7, 0.3], seed=42)

print(f"¡Datos listos para Regresión!")
print(f"Registros de entrenamiento: {train_reg.count()} | Registros de prueba: {test_reg.count()}")
# Out:
# ¡Datos listos para Regresión!
# Registros de entrenamiento: 3995 | Registros de prueba: 1599

# %%
from pyspark.ml.regression import LinearRegression

# 1. Configurar el modelo de Regresión Lineal
# Usamos las nuevas características que no incluyen el precio (scaledFeatures_regresion)
# y apuntamos a la variable objetivo correcta (label_precio)
lr_regresion = LinearRegression(
    featuresCol="scaledFeatures_regresion",
    labelCol="label_precio",
    maxIter=10
)

# 2. Entrenar el modelo con el 70% de los datos de regresión (train_reg)
lr_reg_model = lr_regresion.fit(train_reg)

# 3. Hacer las predicciones sobre el 30% de los datos de prueba (test_reg)
predictions_regresion = lr_reg_model.transform(test_reg)

# 4. Mostrar las predicciones junto al precio real y las características de tu proyecto
print("=== COMPARATIVA: PRECIO REAL VS PRECIO PREDICHO ===")
predictions_regresion.select(
    "supermercado", 
    "categoria", 
    "marca", 
    "label_precio", 
    "prediction"
).show(10, truncate=False)
# Out:
# === COMPARATIVA: PRECIO REAL VS PRECIO PREDICHO ===
# +------------+----------------+-------+------------+------------------+
# |supermercado|categoria       |marca  |label_precio|prediction        |
# +------------+----------------+-------+------------+------------------+
# |Acuenta     |Aceites         |ACE    |1190.0      |4327.791780412615 |
# |Acuenta     |Aceites         |ACE    |2650.0      |4327.791780412615 |
# |Acuenta     |Aceites         |ACE    |3690.0      |4327.791780412615 |
# |Acuenta     |Aceites         |ACE    |4590.0      |4327.791780412615 |
# |Acuenta     |Aceites         |ACE    |14490.0     |4327.791780412615 |
# |Acuenta     |Despensa General|ACE    |570.0       |2901.9066976778395|
# |Acuenta     |Despensa General|ACE    |2890.0      |2901.9066976778395|
# |ACUENTA     |Aves            |ACUENTA|2800.0      |2000.981819023198 |
# |ACUENTA     |Elaborados      |ACUENTA|2800.0      |3521.925907273625 |
# |ACUENTA     |Lácteos         |ACUENTA|2590.0      |955.3327583510295 |
# +------------+----------------+-------+------------+------------------+
# only showing top 10 rows

# %%
from pyspark.ml.evaluation import RegressionEvaluator

# 1. Configurar los evaluadores de regresión apuntando a las columnas correctas
evaluator_r2 = RegressionEvaluator(labelCol="label_precio", predictionCol="prediction", metricName="r2")
evaluator_rmse = RegressionEvaluator(labelCol="label_precio", predictionCol="prediction", metricName="rmse")

# 2. Evaluar el DataFrame de las predicciones para obtener las métricas matemáticas
r2 = evaluator_r2.evaluate(predictions_regresion)
rmse = evaluator_rmse.evaluate(predictions_regresion)

# 3. Imprimir el cuadro de resultados limpio y formateado
print("==================================================")
print("     EVALUACIÓN DE LA REGRESIÓN (SEMANA 12)       ")
print("==================================================")
print(f"R² (Coeficiente de Determinación): {r2 * 100:.2f}%")
print(f"RMSE (Error promedio del modelo):  ${rmse:.2f} CLP")
print("==================================================")
# Out:
# ==================================================
#      EVALUACIÓN DE LA REGRESIÓN (SEMANA 12)
# ==================================================
# R² (Coeficiente de Determinación): 3.38%
# RMSE (Error promedio del modelo):  $6033.28 CLP
# ==================================================

# %%
# Imprimir la intersección (b) y los coeficientes (m) adaptados a tu proyecto
print("=== PARÁMETROS DE LA ECUACIÓN DE REGRESIÓN ===")
print(f"Intersección (Precio base promedio): ${lr_reg_model.intercept:.2f} CLP")
print(f"Coeficiente de 'supermercado_index':  {lr_reg_model.coefficients[0]:.4f}")
print(f"Coeficiente de 'categoria_index':     {lr_reg_model.coefficients[1]:.4f}")
# Out:
# === PARÁMETROS DE LA ECUACIÓN DE REGRESIÓN ===
# Intersección (Precio base promedio): $4848.48 CLP
# Coeficiente de 'supermercado_index':  -1431.1893
# Coeficiente de 'categoria_index':     596.8204

# %% [markdown]
# 1. ¿El problema es el algoritmo o los datos?
#
# El problema principal esta en los datos, ya que el algoritmo lineal o la regresión se limita a procesar las variables que se le entregan, pero no tiene la información detallada que se necesita para calcular el precio real, lo que hace que los datos originales se queden cortos ante un mercado tan complejo como el retail alimenticio.
#
#
#
# 2. ¿Cómo lo solucionarían en el mundo real sin hacer trampa? qué datos faltan en el dataset original que sí determinen el precio de un producto veterinari
# (por ejemplo  costo de la materia prima, margen de ganancia de la tiena
# si es importado o nacional, peso neto del empaque, etc.). O en sus dot  ,
# como fué el algtmo?
#
# ri
# La fecha de vencimiento influye mucho, ya que los laboratorios bajan los precios de los remedios que están por vencer para liberar stock rápidamente, otro caso es si el fármaco es importado, aquí el valor sube por el transporte internacional y los aranceles, a diferencia de los tratamientos fabricadnacionalmentenal.
#
# Con el Spark se aplico un pipeline para transformar las variables categóricas en variables númericos, de esta forma se puede entrenar el modelo de regresión lineal para predecir el precio base prome.
# ?o?
